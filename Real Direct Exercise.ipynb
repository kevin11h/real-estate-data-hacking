# %% [markdown]
# # Brooklyn Hip Housing Data

# %% [markdown]
# # Author: Benjamin Reddy

# %% [markdown]
# ##  Data Source
#
# https://github.com/oreillymedia/doing_data_science

# %%
library(plyr)

# %%
require(gdata)

# %%
bk <- read.xls("~/gh/doing-data-science//chapter-2-statistical-inference-EDA-and-data-science-process/dds_datasets/rollingsales_brooklyn.xls", pattern="BOROUGH")
head(bk)
# Out:
#   BOROUGH NEIGHBORHOOD
# 1 3
# 2 3
# 3 3
# 4 3
# 5 3
# 6 3
#   BUILDING.CLASS.CATEGORY                      TAX.CLASS.AT.PRESENT BLOCK LOT
# 1 15  CONDOS - 2-10 UNIT RESIDENTIAL                                 814  1103
# 2 15  CONDOS - 2-10 UNIT RESIDENTIAL                                 814  1105
# 3 15  CONDOS - 2-10 UNIT RESIDENTIAL                                1967  1401
# 4 15  CONDOS - 2-10 UNIT RESIDENTIAL                                1967  1402
# 5 15  CONDOS - 2-10 UNIT RESIDENTIAL                                1967  1403
# 6 15  CONDOS - 2-10 UNIT RESIDENTIAL                                1967  1404
#   EASE.MENT BUILDING.CLASS.AT.PRESENT ADDRESS
# 1 NA                                  342 53RD    STREET
# 2 NA                                  342 53RD    STREET
# 3 NA                                  290 GREENE AVE
# 4 NA                                  290 GREENE AVE
# 5 NA                                  290 GREENE AVE
# 6 NA                                  290 GREENE AVE
#   APART.MENT.NUMBER ⋯ RESIDENTIAL.UNITS COMMERCIAL.UNITS TOTAL.UNITS
# 1                   ⋯ 0                 0                0
# 2                   ⋯ 0                 0                0
# 3                   ⋯ 0                 0                0
# 4                   ⋯ 0                 0                0
# 5                   ⋯ 0                 0                0
# 6                   ⋯ 0                 0                0
#   LAND.SQUARE.FEET GROSS.SQUARE.FEET YEAR.BUILT TAX.CLASS.AT.TIME.OF.SALE
# 1 0                0                 0          2
# 2 0                0                 0          2
# 3 0                0                 0          2
# 4 0                0                 0          2
# 5 0                0                 0          2
# 6 0                0                 0          2
#   BUILDING.CLASS.AT.TIME.OF.SALE SALE.PRICE SALE.DATE
# 1 R1                             $403,572   2013-07-09
# 2 R1                             $218,010   2013-07-12
# 3 R1                             $952,311   2013-04-25
# 4 R1                             $842,692   2013-04-25
# 5 R1                             $815,288   2013-04-25
# 6 R1                             $815,288   2013-04-25

# %%
summary(bk)
# Out:
#     BOROUGH                     NEIGHBORHOOD
#  Min.   :3   BEDFORD STUYVESANT       : 1699
#  1st Qu.:3   EAST NEW YORK            : 1394
#  Median :3   BOROUGH PARK             : 1020
#  Mean   :3   BUSHWICK                 :  898
#  3rd Qu.:3   CROWN HEIGHTS            :  886
#  Max.   :3   PARK SLOPE               :  848
#              (Other)                  :16628
#                                  BUILDING.CLASS.CATEGORY TAX.CLASS.AT.PRESENT
#  02  TWO FAMILY HOMES                        :5776       1      :10976
#  01  ONE FAMILY HOMES                        :2890       2      : 6070
#  13  CONDOS - ELEVATOR APARTMENTS            :2739       4      : 2445
#  03  THREE FAMILY HOMES                      :2255       2A     : 1512
#  10  COOPS - ELEVATOR APARTMENTS             :2129       2C     : 1024
#  07  RENTALS - WALKUP APARTMENTS             :1755       1B     :  422
#  (Other)                                     :5829       (Other):  924
#      BLOCK           LOT         EASE.MENT      BUILDING.CLASS.AT.PRESENT
#  Min.   :  20   Min.   :   1.0   Mode:logical   R4     : 2703
#  1st Qu.:1638   1st Qu.:  22.0   NA's:23373     C0     : 2258
#  Median :3839   Median :  48.0                  D4     : 2125
#  Mean   :3984   Mean   : 305.4                  B1     : 2080
#  3rd Qu.:6259   3rd Qu.: 142.0                  B3     : 1229
#  Max.   :8955   Max.   :9039.0                  B2     : 1115
#                                                 (Other):11863
#                                       ADDRESS         APART.MENT.NUMBER
#  163 WASHINGTON AVENUE                    :  106               :17632
#  205 WATER STREET                         :   76   4           :  204
#  380 COZINE AVENUE                        :   65   6           :  183
#  34 NORTH 7TH   STREET                    :   63   3           :  155
#  12399 FLATLANDS AVENUE                   :   62   2           :  144
#  306 GOLD STREET                          :   62   1           :  125
#  (Other)                                  :22939   (Other)     : 4930
#     ZIP.CODE     RESIDENTIAL.UNITS COMMERCIAL.UNITS    TOTAL.UNITS
#  Min.   :    0   Min.   :  0.000   Min.   :  0.0000   Min.   :  0.00
#  1st Qu.:11209   1st Qu.:  1.000   1st Qu.:  0.0000   1st Qu.:  1.00
#  Median :11218   Median :  1.000   Median :  0.0000   Median :  1.00
#  Mean   :11211   Mean   :  2.156   Mean   :  0.1973   Mean   :  2.37
#  3rd Qu.:11230   3rd Qu.:  2.000   3rd Qu.:  0.0000   3rd Qu.:  2.00
#  Max.   :11416   Max.   :509.000   Max.   :222.0000   Max.   :509.00
#
#  LAND.SQUARE.FEET GROSS.SQUARE.FEET   YEAR.BUILT   TAX.CLASS.AT.TIME.OF.SALE
#  0      : 8027    0      : 8934     Min.   :   0   Min.   :1.000
#  2,000  : 2201    3,000  :  230     1st Qu.:1901   1st Qu.:1.000
#  2,500  : 1149    3,600  :  189     Median :1925   Median :1.000
#  1,800  :  597    2,400  :  185     Mean   :1681   Mean   :1.705
#  4,000  :  474    2,700  :  146     3rd Qu.:1950   3rd Qu.:2.000
#  3,000  :  307    3,300  :  139     Max.   :2013   Max.   :4.000
#  (Other):10618    (Other):13550
#  BUILDING.CLASS.AT.TIME.OF.SALE    SALE.PRICE         SALE.DATE
#  R4     : 2739                  $0      : 8791   2012-09-27:  675
#  C0     : 2255                  $10     :  241   2012-12-27:  245
#  D4     : 2125                  $700,000:  138   2012-12-20:  222
#  B1     : 2070                  $650,000:  129   2013-03-22:  204
#  B3     : 1230                  $300,000:  120   2012-12-31:  179
#  B2     : 1115                  $600,000:  120   2012-12-19:  178
#  (Other):11839                  (Other) :13834   (Other)   :21670

# %%
bk$SALE.PRICE.N <- as.numeric(gsub("[^[:digit:]]", "", bk$SALE.PRICE))

# %%
count(is.na(bk$SALE.PRICE.N))
# Out:
#   x     freq
# 1 FALSE 23373

# %%
names(bk) <- tolower(names(bk))

# %% [markdown]
# ## clean / format the data with regular expressions

# %%
bk$gross.sqft <- as.numeric(gsub("[^[:digit:]]", "", bk$gross.square.feet))
bk$land.sqft <- as.numeric(gsub("[^[:digit:]]", "", bk$land.square.feet))

# %%
bk$sale.date <- as.Date(bk$sale.date)
bk$year.built <- as.numeric(as.character(bk$year.built))

# %% [markdown]
# ## do a bit of exploration to make sure there's not anything
# ## weird going on with sale prices

# %%
attach(bk)
# Out:
# The following objects are masked from bk (pos = 3):
#
#     address, apart.ment.number, block, borough,
#     building.class.at.present, building.class.at.time.of.sale,
#     building.class.category, commercial.units, ease.ment, gross.sqft,
#     gross.square.feet, land.sqft, land.square.feet, lot, neighborhood,
#     residential.units, sale.date, sale.price, sale.price.n,
#     tax.class.at.present, tax.class.at.time.of.sale, total.units,
#     year.built, zip.code
#
# The following objects are masked from bk (pos = 4):
#
#     address, apart.ment.number, block, borough,
#     building.class.at.present, building.class.at.time.of.sale,
#     building.class.category, commercial.units, ease.ment, gross.sqft,
#     gross.square.feet, land.sqft, land.square.feet, lot, neighborhood,
#     residential.units, sale.date, sale.price, tax.class.at.present,
#     tax.class.at.time.of.sale, total.units, year.built, zip.code
#
# The following objects are masked from bk (pos = 5):
#
#     address, apart.ment.number, block, borough,
#     building.class.at.present, building.class.at.time.of.sale,
#     building.class.category, commercial.units, ease.ment, gross.sqft,
#     gross.square.feet, land.sqft, land.square.feet, lot, neighborhood,
#     residential.units, sale.date, sale.price, tax.class.at.present,
#     tax.class.at.time.of.sale, total.units, year.built, zip.code
#
# The following objects are masked from bk (pos = 6):
#
#     address, apart.ment.number, block, borough,
#     building.class.at.present, building.class.at.time.of.sale,
#     building.class.category, commercial.units, ease.ment, gross.sqft,
#     gross.square.feet, land.sqft, land.square.feet, lot, neighborhood,
#     residential.units, sale.date, sale.price, tax.class.at.present,
#     tax.class.at.time.of.sale, total.units, year.built, zip.code

# %%
hist(sale.price.n)
# Out:
# Plot with title “Histogram of sale.price.n”

# %%
hist(sale.price.n[sale.price.n>0])
# Out:
# Plot with title “Histogram of sale.price.n[sale.price.n > 0]”

# %%
hist(gross.sqft[sale.price.n==0])
# Out:
# Plot with title “Histogram of gross.sqft[sale.price.n == 0]”

# %%
detach(bk)

# %% [markdown]
# ## Keep only the Actual Sales

# %%
bk.sale <- bk[bk$sale.price.n!=0,]

# %%
plot(bk.sale$gross.sqft, bk.sale$sale.price.n)
# Out:
# plot without title

# %%
plot(log(bk.sale$gross.sqft), log(bk.sale$sale.price.n))
# Out:
# plot without title

# %% [markdown]
# ## for now, let's look at 1-, 2-, and 3-family homes

# %%
bk.homes <- bk.sale[which(grepl("FAMILY",
            bk.sale$building.class.category)),]

plot(log(bk.homes$gross.sqft), log(bk.homes$sale.price.n))
# Out:
# plot without title

# %%
bk.homes[which(bk.homes$sale.price.n<100000),][order(bk.homes[which(bk.homes$sale.price.n<100000),]$sale.price.n),]
# Out:
#       borough neighborhood
# 1201  3       BEDFORD STUYVESANT
# 1451  3       BEDFORD STUYVESANT
# 2870  3       BENSONHURST
# 2937  3       BENSONHURST
# 3155  3       BENSONHURST
# 5631  3       BROWNSVILLE
# 5949  3       BUSHWICK
# 5969  3       BUSHWICK
# 6900  3       CANARSIE
# 7156  3       CANARSIE
# 7204  3       CANARSIE
# 8644  3       CROWN HEIGHTS
# 8767  3       CROWN HEIGHTS
# 10529 3       DYKER HEIGHTS
# 10974 3       EAST NEW YORK
# 12631 3       FLATBUSH-EAST
# 12672 3       FLATBUSH-EAST
# 12730 3       FLATBUSH-EAST
# 12841 3       FLATBUSH-EAST
# 14524 3       GRAVESEND
# 14576 3       GRAVESEND
# 15819 3       MADISON
# 17101 3       OCEAN HILL
# 18013 3       OCEAN PARKWAY-SOUTH
# 18673 3       PARK SLOPE
# 20359 3       SHEEPSHEAD BAY
# 23098 3       WINDSOR TERRACE
# 102   3       BATH BEACH
# 117   3       BATH BEACH
# 373   3       BAY RIDGE
# ⋮     ⋮       ⋮
# 14044 3       GERRITSEN BEACH
# 16415 3       MIDWOOD
# 21769 3       WILLIAMSBURG-EAST
# 10358 3       DYKER HEIGHTS
# 5655  3       BROWNSVILLE
# 1325  3       BEDFORD STUYVESANT
# 1872  3       BEDFORD STUYVESANT
# 14546 3       GRAVESEND
# 20199 3       SHEEPSHEAD BAY
# 6793  3       CANARSIE
# 10311 3       DYKER HEIGHTS
# 20853 3       SUNSET PARK
# 13665 3       FLATLANDS
# 7106  3       CANARSIE
# 12199 3       FLATBUSH-CENTRAL
# 12200 3       FLATBUSH-CENTRAL
# 17247 3       OCEAN HILL
# 3832  3       BOROUGH PARK
# 12154 3       FLATBUSH-CENTRAL
# 8805  3       CROWN HEIGHTS
# 21504 3       WILLIAMSBURG-CENTRAL
# 14000 3       GERRITSEN BEACH
# 1484  3       BEDFORD STUYVESANT
# 6789  3       CANARSIE
# 11138 3       EAST NEW YORK
# 14030 3       GERRITSEN BEACH
# 85    3       BATH BEACH
# 10896 3       EAST NEW YORK
# 5952  3       BUSHWICK
# 8755  3       CROWN HEIGHTS
#       building.class.category                      tax.class.at.present block
# 1201  01  ONE FAMILY HOMES                         1                    1706
# 1451  02  TWO FAMILY HOMES                         1                    1678
# 2870  01  ONE FAMILY HOMES                         1                    6170
# 2937  02  TWO FAMILY HOMES                         1                    5561
# 3155  03  THREE FAMILY HOMES                       1                    5562
# 5631  01  ONE FAMILY HOMES                         1                    3541
# 5949  02  TWO FAMILY HOMES                         1                    3273
# 5969  02  TWO FAMILY HOMES                         1                    3296
# 6900  02  TWO FAMILY HOMES                         1                    4748
# 7156  02  TWO FAMILY HOMES                         1                    8270
# 7204  03  THREE FAMILY HOMES                       1                    7962
# 8644  02  TWO FAMILY HOMES                         1                    1251
# 8767  02  TWO FAMILY HOMES                         1                    1373
# 10529 02  TWO FAMILY HOMES                         1                    6244
# 10974 02  TWO FAMILY HOMES                         1                    4252
# 12631 01  ONE FAMILY HOMES                         1                    4969
# 12672 01  ONE FAMILY HOMES                         1                    5014
# 12730 01  ONE FAMILY HOMES                         1                    7723
# 12841 02  TWO FAMILY HOMES                         1                    4892
# 14524 02  TWO FAMILY HOMES                         1                    6882
# 14576 02  TWO FAMILY HOMES                         1                    7086
# 15819 02  TWO FAMILY HOMES                         1                    7338
# 17101 02  TWO FAMILY HOMES                         1                    1538
# 18013 01  ONE FAMILY HOMES                         1                    7105
# 18673 02  TWO FAMILY HOMES                         1                    1078
# 20359 02  TWO FAMILY HOMES                         1                    7476
# 23098 02  TWO FAMILY HOMES                         1                     877
# 102   02  TWO FAMILY HOMES                         1                    6413
# 117   02  TWO FAMILY HOMES                         1                    6433
# 373   01  ONE FAMILY HOMES                         1                    5967
# ⋮     ⋮                                            ⋮                    ⋮
# 14044 02  TWO FAMILY HOMES                         1                    8829
# 16415 01  ONE FAMILY HOMES                         1                    7573
# 21769 02  TWO FAMILY HOMES                         1                    2739
# 10358 01  ONE FAMILY HOMES                         1                    6220
# 5655  01  ONE FAMILY HOMES                         1                    3831
# 1325  02  TWO FAMILY HOMES                         1                    1626
# 1872  03  THREE FAMILY HOMES                       1                    1667
# 14546 02  TWO FAMILY HOMES                         1                    6913
# 20199 01  ONE FAMILY HOMES                         1                    8796
# 6793  01  ONE FAMILY HOMES                         1                    8006
# 10311 01  ONE FAMILY HOMES                         1                    5946
# 20853 02  TWO FAMILY HOMES                         1                     657
# 13665 02  TWO FAMILY HOMES                         1                    7822
# 7106  02  TWO FAMILY HOMES                         1                    8233
# 12199 02  TWO FAMILY HOMES                         1                    5168
# 12200 02  TWO FAMILY HOMES                         1                    5168
# 17247 03  THREE FAMILY HOMES                       1                    1569
# 3832  01  ONE FAMILY HOMES                         1                    5501
# 12154 02  TWO FAMILY HOMES                         1                    5073
# 8805  02  TWO FAMILY HOMES                         1                    1420
# 21504 03  THREE FAMILY HOMES                       1                    2231
# 14000 01  ONE FAMILY HOMES                         1                    8856
# 1484  02  TWO FAMILY HOMES                         1                    1695
# 6789  01  ONE FAMILY HOMES                         1                    7992
# 11138 03  THREE FAMILY HOMES                       1                    4066
# 14030 01  ONE FAMILY HOMES                         1                    8939
# 85    02  TWO FAMILY HOMES                         1                    6394
# 10896 02  TWO FAMILY HOMES                         1                    4078
# 5952  02  TWO FAMILY HOMES                         1                    3273
# 8755  02  TWO FAMILY HOMES                         1                    1368
#       lot  ease.ment building.class.at.present
# 1201   23  NA        A5
# 1451   40  NA        B3
# 2870   78  NA        A9
# 2937   52  NA        B2
# 3155    4  NA        C0
# 5631  138  NA        A5
# 5949   47  NA        B3
# 5969  105  NA        B2
# 6900   22  NA        B1
# 7156   54  NA        B2
# 7204   88  NA        C0
# 8644   22  NA        B9
# 8767   76  NA        B1
# 10529 157  NA        B1
# 10974   7  NA        B1
# 12631  32  NA        A9
# 12672  38  NA        A1
# 12730  10  NA        A9
# 12841  21  NA        B9
# 14524  22  NA        B1
# 14576  70  NA        B3
# 15819  26  NA        B1
# 17101 138  NA        B2
# 18013  85  NA        A1
# 18673  50  NA        B3
# 20359  77  NA        B1
# 23098  12  NA        B9
# 102    65  NA        B3
# 117    11  NA        B3
# 373     3  NA        A1
# ⋮     ⋮    ⋮         ⋮
# 14044   70 NA        B1
# 16415    5 NA        A9
# 21769    3 NA        B9
# 10358   62 NA        A5
# 5655    14 NA        A5
# 1325    37 NA        B3
# 1872    52 NA        C0
# 14546   52 NA        B2
# 20199  130 NA        A2
# 6793    35 NA        A2
# 10311   65 NA        A5
# 20853   41 NA        S2
# 13665   18 NA        B1
# 7106    36 NA        B2
# 12199   49 NA        B9
# 12200   49 NA        B9
# 17247   14 NA        C0
# 3832    63 NA        A5
# 12154   39 NA        S2
# 8805    32 NA        B1
# 21504   62 NA        C0
# 14000 1570 NA        A1
# 1484    11 NA        B1
# 6789    29 NA        A2
# 11138   28 NA        C0
# 14030  118 NA        A2
# 85      36 NA        B1
# 10896    5 NA        B3
# 5952    61 NA        B3
# 8755    45 NA        B9
# 117   B3                             $10        2012-11-13 10
# 373   A1                             $10        2013-05-14 10
# ⋮     ⋮                              ⋮          ⋮          ⋮
# 14044 B1                             $75,000    2012-09-28 75000
# 16415 A9                             $75,000    2012-08-27 75000
# 21769 B9                             $75,432    2012-08-14 75432
# 10358 A5                             $76,000    2013-06-17 76000
# 5655  A5                             $78,930    2013-04-01 78930
# 1325  B3                             $80,000    2012-08-08 80000
# 1872  C0                             $80,000    2012-09-20 80000
# 14546 B2                             $80,000    2013-07-23 80000
# 20199 A2                             $81,000    2013-07-11 81000
# 6793  A2                             $85,000    2012-10-12 85000
# 10311 A5                             $85,000    2013-05-03 85000
# 20853 S2                             $85,000    2013-03-15 85000
# 13665 B1                             $87,476    2013-03-19 87476
# 7106  B2                             $90,000    2012-09-09 90000
# 12199 B9                             $90,000    2013-02-19 90000
# 12200 B9                             $90,000    2013-02-19 90000
# 17247 C0                             $90,000    2013-03-11 90000
# 3832  A5                             $91,041    2013-02-06 91041
# 12154 S2                             $91,400    2013-04-19 91400
# 8805  B1                             $91,635    2013-03-18 91635
# 21504 C0                             $92,000    2013-03-21 92000
# 14000 A1                             $92,500    2013-01-23 92500
# 1484  B1                             $95,000    2012-11-19 95000
# 6789  A2                             $95,000    2013-05-29 95000
# 11138 C0                             $95,000    2013-04-29 95000
# 14030 A2                             $95,000    2013-07-16 95000
# 85    B1                             $97,500    2012-11-20 97500
# 10896 B3                             $98,000    2013-06-25 98000
# 5952  B3                             $99,000    2012-11-21 99000
# 8755  B9                             $99,000    2013-02-15 99000
#       gross.sqft land.sqft
# 1201  1452       2173
# 1451  2592       1800
# 2870  1569       1742
# 2937  2064       3000
# 3155  2394       3000
# 5631  1148       1800
# 5949  1920       1667
# 5969  3216       2133
# 6900  1624       3500
# 7156  2448       4750
# 7204  1800       2000
# 8644  3509       2512
# 8767  3492       3160
# 10529 1440       2000
# 10974 3120       1940
# 12631 1152       2500
# 12672 1660       4000
# 12730 1316       2000
# 12841 1832       2000
# 14524 2280       2248
# 14576 1120       3814
# 15819 1976       2367
# 17101 2246       2050
# 18013 1616       2708
# 18673 4168       1900
# 20359 2251       2500
# 23098 2080       2003
# 102   2000       2900
# 117   2490       1906
# 373   2288       3000
# ⋮     ⋮          ⋮
# 14044 1563       1992
# 16415 1821       2500
# 21769 1440       1250
# 10358 1532       1925
# 5655  1116       1802
# 1325  2868       1875
# 1872  2576       2000
# 14546 1848       1933
# 20199  568       1663
# 6793   960       2000
# 10311 1288       1800
# 20853 2400       1251
# 13665 1998       1825
# 7106  2142       3050
# 12199 2000       2000
# 12200 2000       2000
# 17247 2613       1853
# 3832  2528       2003
# 12154 3116       1979
# 8805  1944       1279
# 21504 2295       1700
# 14000 2025       1800
# 1484   986       2400
# 6789   753       2580
# 11138 2560       2250
# 14030  640       1785
# 85    3240       2344
# 10896 1730       2000
# 5952  2040       1750
# 8755  1240        849

# %% [markdown]
# ## remove outliers that seem like they weren't actual sales

# %%
bk.homes$outliers <- (log(bk.homes$sale.price.n) <= 5) + 0
bk.homes <- bk.homes[which(bk.homes$outliers==0),]

plot(log(bk.homes$gross.sqft), log(bk.homes$sale.price.n))
# Out:
# plot without title
